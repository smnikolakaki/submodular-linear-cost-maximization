# %% [markdown]
# ### Import packages

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import os
import sys
import dill
import yaml
import numpy as np
import pandas as pd
import ast

import seaborn as sns
sns.set(style='ticks')

# %% [markdown]
# ### Import submodular-optimization packages

# %%
sys.path.insert(1, "/home/grad3/harshal/Projects/submodular-optimization/submodular_optimization/")

# %% [markdown]
# ### Visualizations directory

# %%
VIZ_DIR = os.path.abspath("/home/grad3/harshal/Projects/submodular-optimization/viz/")

# %% [markdown]
# ### Plotting utilities

# %%
def set_style():
    # This sets reasonable defaults for font size for a paper
    sns.set_context("paper")    
    # Set the font to be serif
    sns.set(font='serif')#, rc={'text.usetex' : True})   
    # Make the background white, and specify the specific font family
    sns.set_style("white", {
        "font.family": "serif",
        "font.serif": ["Times", "Palatino", "serif"]
    })
    # Set tick size for axes
    sns.set_style("ticks", {"xtick.major.size": 6, "ytick.major.size": 6})

# %%
def set_size(fig, width=6, height=4):
    fig.set_size_inches(width, height)
    plt.tight_layout()

# %%
def save_fig(fig, filename):
    fig.savefig(os.path.join(VIZ_DIR, filename), dpi=600, format='pdf', bbox_inches='tight')

# %% [markdown]
# ### Plots

# %%
df = pd.read_csv("/research/data-x/submodular-optimization/experiment_01.csv",
                header=0,
                index_col=False)

# %% [markdown]
# #### Performance evaluation of lazy evaluation epsilon

# %%
def plot_lazy_evaluation_performance(df):
    # Cost Scaled Lazy Greedy
    g = sns.lineplot(x='lazy_epsilon', y='val', data=df[df.alg=='cost_scaled_lazy_greedy'], color='blue',
                    label='cost_scaled_lazy_greedy', marker='o')

    ax = plt.gca()
    fig = plt.gcf()
    
    # Cost Distorted Greedy
    distorted_greedy_performance = df[df.alg=='distorted_greedy'].iloc[0]['val']
    ax.hlines(y=distorted_greedy_performance, xmin=0.01, xmax=0.99, color='red', linestyle=':',
              label='distorted_greedy')
    
    # Legend
    labels = ['cost_scaled_lazy_greedy', 'distorted_greedy']
    handles, _ = ax.get_legend_handles_labels()
    plt.legend(handles=handles, labels=labels)

    plt.xlabel('Epsilon value during lazy evaluation')
    plt.ylabel('Value of objective function')
    plt.title('Performance of Lazy Greedy Algorithms')
    return fig, ax

# %%
df0 = df[df.scaling_factor==1]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==50]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==100]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==200]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==300]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==400]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==500]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==600]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==700]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==800]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==900]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)

# %%
df0 = df[df.scaling_factor==1000]
set_style()
fig, ax = plot_lazy_evaluation_performance(df0)
set_size(fig, 10, 8)
